# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/Winter-Sports/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd # import pandas library

# %%
df = pd.read_excel('/content/drive/MyDrive/Projects/Winter Sports/data/Lab-WinterSports.xlsx') # iomports excel into dataframe
df.head() #display first 5 rows of data
# Out:
#   \n🧪 Lab | Winter Sports
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
